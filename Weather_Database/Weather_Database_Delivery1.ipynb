# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 734

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})      
            
       
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 1 | veraval
# Processing Record 9 of Set 1 | wencheng
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | waddan
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | mossendjo
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | moussoro
# Processing Record 20 of Set 1 | san policarpo
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | dzerzhinskoye
# Processing Record 23 of Set 1 | mangochi
# Processing Record 24 of Set 1 | merauke
# Processing Record 25 of Set 1 | faya
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | aripuana
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | nuuk
# Processing Record 38 of Set 1 | fuling
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | sitka
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | ketchikan
# Processing Record 46 of Set 1 | ko samui
# Processing Record 47 of Set 1 | fort nelson
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | yichun
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 2 | te anau
# Processing Record 5 of Set 2 | north battleford
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | yablonovo
# Processing Record 9 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 2 | vanimo
# Processing Record 11 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 2 | sampit
# Processing Record 13 of Set 2 | hun
# Processing Record 14 of Set 2 | clarence town
# Processing Record 15 of Set 2 | gold coast
# Processing Record 16 of Set 2 | inirida
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | claremore
# Processing Record 19 of Set 2 | kisangani
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | loiza
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | vestmannaeyjar
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | okha
# Processing Record 29 of Set 2 | ambon
# Processing Record 30 of Set 2 | mut
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | dehloran
# Processing Record 33 of Set 2 | sanghar
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | porto seguro
# Processing Record 37 of Set 2 | san quintin
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | ambilobe
# Processing Record 40 of Set 2 | imeni poliny osipenko
# Processing Record 41 of Set 2 | charcas
# Processing Record 42 of Set 2 | dillenburg
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | katobu
# Processing Record 46 of Set 2 | san pedro
# Processing Record 47 of Set 2 | sinnamary
# Processing Record 48 of Set 2 | amli
# Processing Record 49 of Set 2 | xinglongshan
# Processing Record 50 of Set 2 | rimbey
# Processing Record 1 of Set 3 | mamakan
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | bamiantong
# Processing Record 5 of Set 3 | havre-saint-pierre
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | frontera
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | flin flon
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | sturgeon bay
# Processing Record 12 of Set 3 | mogadishu
# Processing Record 13 of Set 3 | lubumbashi
# Processing Record 14 of Set 3 | jalu
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | andenes
# Processing Record 17 of Set 3 | chifeng
# Processing Record 18 of Set 3 | porto novo
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | luanda
# Processing Record 21 of Set 3 | husavik
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | deputatskiy
# Processing Record 24 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 3 | abu samrah
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | honiara
# Processing Record 28 of Set 3 | bandarbeyla
# Processing Record 29 of Set 3 | ventspils
# Processing Record 30 of Set 3 | shikarpur
# Processing Record 31 of Set 3 | latung
# Processing Record 32 of Set 3 | gravdal
# Processing Record 33 of Set 3 | saint-augustin
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | ixtapa
# Processing Record 36 of Set 3 | utinga
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | esperance
# Processing Record 39 of Set 3 | lewistown
# Processing Record 40 of Set 3 | port lincoln
# Processing Record 41 of Set 3 | micheweni
# Processing Record 42 of Set 3 | denizli
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | mitsamiouli
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | teruel
# Processing Record 48 of Set 3 | sola
# Processing Record 49 of Set 3 | ca mau
# Processing Record 50 of Set 3 | mendi
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | touros
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | bathsheba
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | tazovskiy
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | kisumu
# Processing Record 13 of Set 4 | shebalino
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | antananarivo
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | kolvereid
# Processing Record 19 of Set 4 | lata
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | okhotsk
# Processing Record 25 of Set 4 | buraydah
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | maamba
# Processing Record 28 of Set 4 | drakhtik
# Processing Record 29 of Set 4 | madang
# Processing Record 30 of Set 4 | ojinaga
# Processing Record 31 of Set 4 | vao
# Processing Record 32 of Set 4 | kudahuvadhoo
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | abha
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | pak phanang
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | palmer
# Processing Record 39 of Set 4 | ingham
# Processing Record 40 of Set 4 | lakhisarai
# Processing Record 41 of Set 4 | kloulklubed
# Processing Record 42 of Set 4 | pafos
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | silifke
# Processing Record 45 of Set 4 | serro
# Processing Record 46 of Set 4 | homer
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | dzhebariki-khaya
# Processing Record 49 of Set 4 | rorvik
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | praia da vitoria
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | coachella
# Processing Record 5 of Set 5 | kastamonu
# Processing Record 6 of Set 5 | bairiki
# Processing Record 7 of Set 5 | milton
# Processing Record 8 of Set 5 | alvaro obregon
# Processing Record 9 of Set 5 | angoche
# Processing Record 10 of Set 5 | montepuez
# Processing Record 11 of Set 5 | makokou
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | wageningen
# Processing Record 16 of Set 5 | grand island
# Processing Record 17 of Set 5 | shimanovsk
# Processing Record 18 of Set 5 | souillac
# Processing Record 19 of Set 5 | kamenka
# Processing Record 20 of Set 5 | asau
# Processing Record 21 of Set 5 | alta floresta
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | maxixe
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | tautira
# Processing Record 28 of Set 5 | yar-sale
# Processing Record 29 of Set 5 | zelenoborskiy
# Processing Record 30 of Set 5 | kokkola
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | chulman
# Processing Record 33 of Set 5 | atar
# Processing Record 34 of Set 5 | black river
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | nome
# Processing Record 37 of Set 5 | grindavik
# Processing Record 38 of Set 5 | egvekinot
# Processing Record 39 of Set 5 | skorodnoye
# Processing Record 40 of Set 5 | zabol
# Processing Record 41 of Set 5 | dongying
# Processing Record 42 of Set 5 | novonikolayevskiy
# Processing Record 43 of Set 5 | marienburg
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | mahad
# Processing Record 46 of Set 5 | murray bridge
# Processing Record 47 of Set 5 | dumas
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | kearney
# Processing Record 50 of Set 5 | fitii
# Processing Record 1 of Set 6 | sambava
# Processing Record 2 of Set 6 | tabou
# Processing Record 3 of Set 6 | svetlopolyansk
# Processing Record 4 of Set 6 | chicama
# Processing Record 5 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 6 | fukue
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | lodja
# Processing Record 9 of Set 6 | north myrtle beach
# Processing Record 10 of Set 6 | kirakira
# Processing Record 11 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | kapaa
# Processing Record 15 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 6 | rudraprayag
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | bentiu
# Processing Record 20 of Set 6 | ust-tsilma
# Processing Record 21 of Set 6 | olden
# Processing Record 22 of Set 6 | valdivia
# Processing Record 23 of Set 6 | pochutla
# Processing Record 24 of Set 6 | fairbanks
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | muroto
# Processing Record 27 of Set 6 | chokurdakh
# Processing Record 28 of Set 6 | invermere
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | hovd
# Processing Record 31 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 6 | manhattan
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | lalmohan
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | yeppoon
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | great falls
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | porto recanati
# Processing Record 42 of Set 6 | high level
# Processing Record 43 of Set 6 | north platte
# Processing Record 44 of Set 6 | moron
# Processing Record 45 of Set 6 | wukari
# Processing Record 46 of Set 6 | plettenberg bay
# Processing Record 47 of Set 6 | patacamaya
# Processing Record 48 of Set 6 | barabinsk
# Processing Record 49 of Set 6 | dubbo
# Processing Record 50 of Set 6 | itarema
# Processing Record 1 of Set 7 | ribeira grande
# Processing Record 2 of Set 7 | indi
# Processing Record 3 of Set 7 | camacha
# Processing Record 4 of Set 7 | manggar
# Processing Record 5 of Set 7 | acapulco
# Processing Record 6 of Set 7 | noumea
# Processing Record 7 of Set 7 | nizhnyaya tavda
# Processing Record 8 of Set 7 | yulara
# Processing Record 9 of Set 7 | churapcha
# Processing Record 10 of Set 7 | aguimes
# Processing Record 11 of Set 7 | utashinai
# Processing Record 12 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | sisimiut
# Processing Record 15 of Set 7 | peniche
# Processing Record 16 of Set 7 | omboue
# Processing Record 17 of Set 7 | fairview
# Processing Record 18 of Set 7 | yatou
# Processing Record 19 of Set 7 | qaanaaq
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 7 | cidreira
# Processing Record 24 of Set 7 | ewo
# Processing Record 25 of Set 7 | texarkana
# Processing Record 26 of Set 7 | aswan
# Processing Record 27 of Set 7 | san patricio
# Processing Record 28 of Set 7 | aspindza
# Processing Record 29 of Set 7 | tomatlan
# Processing Record 30 of Set 7 | kargasok
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 7 | komsomolskiy
# Processing Record 34 of Set 7 | tapikan
# Processing Record 35 of Set 7 | turangi
# Processing Record 36 of Set 7 | emet
# Processing Record 37 of Set 7 | kodinsk
# Processing Record 38 of Set 7 | ust-nera
# Processing Record 39 of Set 7 | tigil
# Processing Record 40 of Set 7 | fare
# Processing Record 41 of Set 7 | lukh
# Processing Record 42 of Set 7 | san cristobal
# Processing Record 43 of Set 7 | la palma
# Processing Record 44 of Set 7 | pitimbu
# Processing Record 45 of Set 7 | neryungri
# Processing Record 46 of Set 7 | nanortalik
# Processing Record 47 of Set 7 | biak
# Processing Record 48 of Set 7 | nagarote
# Processing Record 49 of Set 7 | taber
# Processing Record 50 of Set 7 | oranjemund
# Processing Record 1 of Set 8 | ales
# Processing Record 2 of Set 8 | shupiyan
# Processing Record 3 of Set 8 | haapu
# City not found. Skipping...
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | ossora
# Processing Record 6 of Set 8 | san carlos de bariloche
# Processing Record 7 of Set 8 | manavalakurichi
# Processing Record 8 of Set 8 | mao
# Processing Record 9 of Set 8 | trairi
# Processing Record 10 of Set 8 | luderitz
# Processing Record 11 of Set 8 | chimoio
# Processing Record 12 of Set 8 | shingu
# Processing Record 13 of Set 8 | toora-khem
# Processing Record 14 of Set 8 | pimentel
# Processing Record 15 of Set 8 | eyl
# Processing Record 16 of Set 8 | olafsvik
# Processing Record 17 of Set 8 | malpe
# Processing Record 18 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 8 | porto de moz
# Processing Record 20 of Set 8 | lethem
# Processing Record 21 of Set 8 | baker city
# Processing Record 22 of Set 8 | awjilah
# Processing Record 23 of Set 8 | banna
# Processing Record 24 of Set 8 | kiunga
# Processing Record 25 of Set 8 | umba
# Processing Record 26 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 27 of Set 8 | ferme-neuve
# Processing Record 28 of Set 8 | tanout
# Processing Record 29 of Set 8 | kantang
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | charters towers
# Processing Record 32 of Set 8 | fort-shevchenko
# Processing Record 33 of Set 8 | pucallpa
# Processing Record 34 of Set 8 | nioro
# Processing Record 35 of Set 8 | enumclaw
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | kavieng
# Processing Record 38 of Set 8 | shenjiamen
# Processing Record 39 of Set 8 | coihaique
# Processing Record 40 of Set 8 | hami
# Processing Record 41 of Set 8 | zhangjiakou
# Processing Record 42 of Set 8 | herat
# Processing Record 43 of Set 8 | liberty
# Processing Record 44 of Set 8 | kutum
# Processing Record 45 of Set 8 | babu
# Processing Record 46 of Set 8 | uk
# City not found. Skipping...
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | zhovti vody
# Processing Record 49 of Set 8 | najran
# Processing Record 50 of Set 8 | cururupu
# Processing Record 1 of Set 9 | qandala
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | kjopsvik
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | talnakh
# Processing Record 6 of Set 9 | bubaque
# Processing Record 7 of Set 9 | esmeraldas
# Processing Record 8 of Set 9 | phuket
# Processing Record 9 of Set 9 | la ronge
# Processing Record 10 of Set 9 | ulaanbaatar
# Processing Record 11 of Set 9 | wenling
# Processing Record 12 of Set 9 | ahuimanu
# Processing Record 13 of Set 9 | tokur
# Processing Record 14 of Set 9 | wanganui
# Processing Record 15 of Set 9 | ahipara
# Processing Record 16 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 9 | cooma
# Processing Record 18 of Set 9 | tiznit
# Processing Record 19 of Set 9 | yaan
# Processing Record 20 of Set 9 | north bend
# Processing Record 21 of Set 9 | ribeira brava
# Processing Record 22 of Set 9 | fuxin
# Processing Record 23 of Set 9 | korla
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | karonga
# Processing Record 27 of Set 9 | tubuala
# Processing Record 28 of Set 9 | dali
# Processing Record 29 of Set 9 | damghan
# Processing Record 30 of Set 9 | skibbereen
# Processing Record 31 of Set 9 | kaeo
# Processing Record 32 of Set 9 | fereydun kenar
# Processing Record 33 of Set 9 | shirokiy
# Processing Record 34 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 9 | aranjuez
# Processing Record 37 of Set 9 | sangar
# Processing Record 38 of Set 9 | busayra
# Processing Record 39 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 9 | byron bay
# Processing Record 41 of Set 9 | starobaltachevo
# Processing Record 42 of Set 9 | maraba
# Processing Record 43 of Set 9 | ternate
# Processing Record 44 of Set 9 | daru
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 9 | roebourne
# Processing Record 48 of Set 9 | maldonado
# Processing Record 49 of Set 9 | meulaboh
# Processing Record 50 of Set 9 | portland
# Processing Record 1 of Set 10 | erdenet
# Processing Record 2 of Set 10 | de aar
# Processing Record 3 of Set 10 | grand gaube
# Processing Record 4 of Set 10 | sao filipe
# Processing Record 5 of Set 10 | clifton
# Processing Record 6 of Set 10 | riyadh
# Processing Record 7 of Set 10 | barra patuca
# Processing Record 8 of Set 10 | llanes
# Processing Record 9 of Set 10 | cachoeira do sul
# Processing Record 10 of Set 10 | tadine
# Processing Record 11 of Set 10 | cap malheureux
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | mgandu
# Processing Record 14 of Set 10 | prince rupert
# Processing Record 15 of Set 10 | gambela
# Processing Record 16 of Set 10 | oytal
# Processing Record 17 of Set 10 | kendari
# Processing Record 18 of Set 10 | victoria
# Processing Record 19 of Set 10 | lorengau
# Processing Record 20 of Set 10 | traipu
# Processing Record 21 of Set 10 | qasigiannguit
# Processing Record 22 of Set 10 | surt
# Processing Record 23 of Set 10 | chara
# Processing Record 24 of Set 10 | bhinmal
# Processing Record 25 of Set 10 | aksay
# Processing Record 26 of Set 10 | whitehorse
# Processing Record 27 of Set 10 | nizhnyaya omka
# Processing Record 28 of Set 10 | bow island
# Processing Record 29 of Set 10 | iwamizawa
# Processing Record 30 of Set 10 | colesberg
# Processing Record 31 of Set 10 | mamlyutka
# Processing Record 32 of Set 10 | lakhipur
# Processing Record 33 of Set 10 | avera
# Processing Record 34 of Set 10 | ushibuka
# Processing Record 35 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 10 | bumba
# Processing Record 37 of Set 10 | zhezkazgan
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | vrangel
# Processing Record 40 of Set 10 | kvitok
# Processing Record 41 of Set 10 | kerema
# Processing Record 42 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 43 of Set 10 | vostok
# Processing Record 44 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 10 | tahta
# Processing Record 46 of Set 10 | cabo san lucas
# Processing Record 47 of Set 10 | vaxjo
# Processing Record 48 of Set 10 | halifax
# Processing Record 49 of Set 10 | bemidji
# Processing Record 50 of Set 10 | khromtau
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | wanaka
# Processing Record 3 of Set 11 | pemberton
# Processing Record 4 of Set 11 | shimoda
# Processing Record 5 of Set 11 | crossville
# Processing Record 6 of Set 11 | tateyama
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | siderno
# Processing Record 9 of Set 11 | gariaband
# Processing Record 10 of Set 11 | lake cowichan
# Processing Record 11 of Set 11 | sobolevo
# Processing Record 12 of Set 11 | zapolyarnyy
# Processing Record 13 of Set 11 | kathmandu
# Processing Record 14 of Set 11 | kaspiyskiy
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | polonnaruwa
# Processing Record 17 of Set 11 | goderich
# Processing Record 18 of Set 11 | filadelfia
# Processing Record 19 of Set 11 | baykit
# Processing Record 20 of Set 11 | batticaloa
# Processing Record 21 of Set 11 | rawson
# Processing Record 22 of Set 11 | antofagasta
# Processing Record 23 of Set 11 | shakawe
# Processing Record 24 of Set 11 | alice springs
# Processing Record 25 of Set 11 | coos bay
# Processing Record 26 of Set 11 | bundaberg
# Processing Record 27 of Set 11 | linares
# Processing Record 28 of Set 11 | padang
# Processing Record 29 of Set 11 | sao joao da barra
# Processing Record 30 of Set 11 | puerto baquerizo moreno
# Processing Record 31 of Set 11 | boyolangu
# Processing Record 32 of Set 11 | ramona
# Processing Record 33 of Set 11 | corrente
# Processing Record 34 of Set 11 | nobres
# Processing Record 35 of Set 11 | portsmouth
# Processing Record 36 of Set 11 | saint anthony
# Processing Record 37 of Set 11 | rodrigues alves
# Processing Record 38 of Set 11 | alihe
# Processing Record 39 of Set 11 | udachnyy
# Processing Record 40 of Set 11 | mpika
# Processing Record 41 of Set 11 | huarmey
# Processing Record 42 of Set 11 | kulim
# Processing Record 43 of Set 11 | pryazha
# Processing Record 44 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 11 | yumen
# Processing Record 46 of Set 11 | mwinilunga
# Processing Record 47 of Set 11 | inhambane
# Processing Record 48 of Set 11 | durazno
# Processing Record 49 of Set 11 | la rioja
# Processing Record 50 of Set 11 | bud
# Processing Record 1 of Set 12 | port-gentil
# Processing Record 2 of Set 12 | puerto madryn
# Processing Record 3 of Set 12 | pringsewu
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | huangchuan
# Processing Record 6 of Set 12 | porbandar
# Processing Record 7 of Set 12 | casambalangan
# Processing Record 8 of Set 12 | ostrovnoy
# Processing Record 9 of Set 12 | dingle
# Processing Record 10 of Set 12 | quang ngai
# Processing Record 11 of Set 12 | hailar
# Processing Record 12 of Set 12 | beian
# Processing Record 13 of Set 12 | parabel
# Processing Record 14 of Set 12 | mandalgovi
# Processing Record 15 of Set 12 | martapura
# Processing Record 16 of Set 12 | monterey
# Processing Record 17 of Set 12 | dafeng
# Processing Record 18 of Set 12 | banda aceh
# Processing Record 19 of Set 12 | seoul
# Processing Record 20 of Set 12 | port moresby
# Processing Record 21 of Set 12 | acari
# Processing Record 22 of Set 12 | qaqortoq
# Processing Record 23 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 12 | bereda
# Processing Record 25 of Set 12 | dabola
# Processing Record 26 of Set 12 | san agustin
# Processing Record 27 of Set 12 | maracacume
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | wufeng
# Processing Record 30 of Set 12 | santiago
# Processing Record 31 of Set 12 | shitkino
# Processing Record 32 of Set 12 | braedstrup
# Processing Record 33 of Set 12 | keetmanshoop
# Processing Record 34 of Set 12 | benghazi
# Processing Record 35 of Set 12 | alamos
# Processing Record 36 of Set 12 | portales
# Processing Record 37 of Set 12 | tingi
# Processing Record 38 of Set 12 | abu kamal
# Processing Record 39 of Set 12 | energeticheskiy
# Processing Record 40 of Set 12 | shiyan
# Processing Record 41 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 12 | nelson bay
# Processing Record 43 of Set 12 | san clemente
# Processing Record 44 of Set 12 | kesinga
# Processing Record 45 of Set 12 | belyy yar
# Processing Record 46 of Set 12 | gimli
# Processing Record 47 of Set 12 | kargala
# Processing Record 48 of Set 12 | bilma
# Processing Record 49 of Set 12 | jibuti
# Processing Record 50 of Set 12 | niquelandia
# Processing Record 1 of Set 13 | hengshui
# Processing Record 2 of Set 13 | khorramshahr
# Processing Record 3 of Set 13 | brandfort
# Processing Record 4 of Set 13 | jaisalmer
# Processing Record 5 of Set 13 | cookshire
# City not found. Skipping...
# Processing Record 6 of Set 13 | tura
# Processing Record 7 of Set 13 | kushima
# Processing Record 8 of Set 13 | mizdah
# Processing Record 9 of Set 13 | ledyard
# Processing Record 10 of Set 13 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 11 of Set 13 | kulhudhuffushi
# Processing Record 12 of Set 13 | flinders
# Processing Record 13 of Set 13 | acarau
# Processing Record 14 of Set 13 | gizo
# Processing Record 15 of Set 13 | kailua
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | tehri
# Processing Record 18 of Set 13 | rena
# Processing Record 19 of Set 13 | aloleng
# Processing Record 20 of Set 13 | san fernando
# Processing Record 21 of Set 13 | sistranda
# Processing Record 22 of Set 13 | marovoay
# Processing Record 23 of Set 13 | parintins
# Processing Record 24 of Set 13 | kokopo
# Processing Record 25 of Set 13 | vilyuysk
# Processing Record 26 of Set 13 | albolote
# Processing Record 27 of Set 13 | humboldt
# Processing Record 28 of Set 13 | puerto leguizamo
# Processing Record 29 of Set 13 | colwyn bay
# Processing Record 30 of Set 13 | sao gabriel da cachoeira
# Processing Record 31 of Set 13 | erzin
# Processing Record 32 of Set 13 | xining
# Processing Record 33 of Set 13 | tashara
# Processing Record 34 of Set 13 | rudnya
# Processing Record 35 of Set 13 | labuhan
# Processing Record 36 of Set 13 | burgersdorp
# Processing Record 37 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 38 of Set 13 | karlshamn
# Processing Record 39 of Set 13 | serafimovich
# Processing Record 40 of Set 13 | miyako
# Processing Record 41 of Set 13 | cajamarca
# Processing Record 42 of Set 13 | kasongo-lunda
# Processing Record 43 of Set 13 | sicamous
# Processing Record 44 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 13 | ganeasa
# Processing Record 46 of Set 13 | juruti
# Processing Record 47 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 13 | beyneu
# Processing Record 49 of Set 13 | bhinga
# Processing Record 50 of Set 13 | ayagoz
# Processing Record 1 of Set 14 | sweetwater
# Processing Record 2 of Set 14 | itanhaem
# Processing Record 3 of Set 14 | muros
# Processing Record 4 of Set 14 | sretensk
# Processing Record 5 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 14 | naze
# Processing Record 7 of Set 14 | sikasso
# Processing Record 8 of Set 14 | santa fe
# Processing Record 9 of Set 14 | jambi
# Processing Record 10 of Set 14 | tanggu
# Processing Record 11 of Set 14 | pavlohrad
# Processing Record 12 of Set 14 | arkhangelsk
# Processing Record 13 of Set 14 | tessalit
# Processing Record 14 of Set 14 | kabalo
# Processing Record 15 of Set 14 | magistralnyy
# Processing Record 16 of Set 14 | leh
# Processing Record 17 of Set 14 | ucluelet
# Processing Record 18 of Set 14 | viedma
# Processing Record 19 of Set 14 | winnemucca
# Processing Record 20 of Set 14 | bowen
# Processing Record 21 of Set 14 | kieta
# Processing Record 22 of Set 14 | mananjary
# Processing Record 23 of Set 14 | aksha
# Processing Record 24 of Set 14 | cordoba
# Processing Record 25 of Set 14 | harstad
# Processing Record 26 of Set 14 | changde
# Processing Record 27 of Set 14 | liverpool
# Processing Record 28 of Set 14 | goundam
# Processing Record 29 of Set 14 | betul
# Processing Record 30 of Set 14 | jiuquan
# Processing Record 31 of Set 14 | khandbari
# Processing Record 32 of Set 14 | awash
# Processing Record 33 of Set 14 | menongue
# Processing Record 34 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 35 of Set 14 | ugoofaaru
# Processing Record 36 of Set 14 | raudeberg
# Processing Record 37 of Set 14 | bajos de haina
# Processing Record 38 of Set 14 | stony plain
# Processing Record 39 of Set 14 | waipawa
# Processing Record 40 of Set 14 | san rafael
# Processing Record 41 of Set 14 | paamiut
# Processing Record 42 of Set 14 | nara
# Processing Record 43 of Set 14 | longhua
# Processing Record 44 of Set 14 | burns lake
# Processing Record 45 of Set 14 | koulamoutou
# Processing Record 46 of Set 14 | tabas
# Processing Record 47 of Set 14 | uvalde
# Processing Record 48 of Set 14 | doboj
# Processing Record 49 of Set 14 | morehead
# Processing Record 50 of Set 14 | bartica
# Processing Record 1 of Set 15 | gat
# Processing Record 2 of Set 15 | san isidro
# Processing Record 3 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 4 of Set 15 | solnechnyy
# Processing Record 5 of Set 15 | helena
# Processing Record 6 of Set 15 | huilong
# Processing Record 7 of Set 15 | jining
# Processing Record 8 of Set 15 | lindsay
# Processing Record 9 of Set 15 | norwich
# Processing Record 10 of Set 15 | monrovia
# Processing Record 11 of Set 15 | sakaiminato
# Processing Record 12 of Set 15 | telgte
# Processing Record 13 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 15 | quime
# Processing Record 15 of Set 15 | hare bay
# Processing Record 16 of Set 15 | paka
# Processing Record 17 of Set 15 | marystown
# Processing Record 18 of Set 15 | progreso
# Processing Record 19 of Set 15 | chimbote
# Processing Record 20 of Set 15 | sucua
# Processing Record 21 of Set 15 | kamaishi
# Processing Record 22 of Set 15 | ambulu
# Processing Record 23 of Set 15 | bat khela
# Processing Record 24 of Set 15 | chillan
# Processing Record 25 of Set 15 | aksu
# Processing Record 26 of Set 15 | xai-xai
# Processing Record 27 of Set 15 | cacule
# Processing Record 28 of Set 15 | chernyshevskiy
# Processing Record 29 of Set 15 | ayan
# Processing Record 30 of Set 15 | finnsnes
# Processing Record 31 of Set 15 | altay
# Processing Record 32 of Set 15 | sari
# Processing Record 33 of Set 15 | rio cuarto
# Processing Record 34 of Set 15 | rio gallegos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City  Cloudiness Country Current Description                 Date  \
# 0      Vaini          75      TO    scattered clouds  2022-10-04 04:06:01
# 1     Dikson         100      RU    scattered clouds  2022-10-04 04:04:42
# 2     Hobart          40      AU    scattered clouds  2022-10-04 04:01:57
# 3     Albany         100      US    scattered clouds  2022-10-04 04:06:01
# 4    Mataura          99      NZ    scattered clouds  2022-10-04 04:06:02
# 5     Torbay           7      CA    scattered clouds  2022-10-04 04:05:33
# 6    Veraval          94      IN    scattered clouds  2022-10-04 04:06:03
# 7   Wencheng         100      CN    scattered clouds  2022-10-04 04:06:03
# 8     Waddan          85      LY    scattered clouds  2022-10-04 04:06:04
# 9  Busselton           0      AU    scattered clouds  2022-10-04 04:06:04
#
#    Humidity      Lat       Lng  Max Temp  Wind Speed
# 0        74 -21.2000 -175.2000     80.76       12.66
# 1        99  73.5069   80.5464     31.82        5.12
# 2        59 -42.8794  147.3294     55.26       13.80
# 3        79  42.6001  -73.9662     48.45        4.14
# 4        99 -46.1927  168.8643     41.79        6.13
# 5        80  47.6666  -52.7314     41.40        4.00
# 6        74  20.9000   70.3667     81.27        6.87
# 7        88  33.0559  113.7978     48.34       20.69
# 8        86  29.1614   16.1390     67.68        6.08
# 9        60 -33.6500  115.3333     62.40       13.29

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Current Description', 'Date',
#        'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df [new_column_order]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000     80.76        74          75
# 1     Dikson      RU  73.5069   80.5464     31.82        99         100
# 2     Hobart      AU -42.8794  147.3294     55.26        59          40
# 3     Albany      US  42.6001  -73.9662     48.45        79         100
# 4    Mataura      NZ -46.1927  168.8643     41.79        99          99
# 5     Torbay      CA  47.6666  -52.7314     41.40        80           7
# 6    Veraval      IN  20.9000   70.3667     81.27        74          94
# 7   Wencheng      CN  33.0559  113.7978     48.34        88         100
# 8     Waddan      LY  29.1614   16.1390     67.68        86          85
# 9  Busselton      AU -33.6500  115.3333     62.40        60           0
#
#    Wind Speed Current Description
# 0       12.66    scattered clouds
# 1        5.12    scattered clouds
# 2       13.80    scattered clouds
# 3        4.14    scattered clouds
# 4        6.13    scattered clouds
# 5        4.00    scattered clouds
# 6        6.87    scattered clouds
# 7       20.69    scattered clouds
# 8        6.08    scattered clouds
# 9       13.29    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).We already create a new folder named "weather_data" to save the file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
